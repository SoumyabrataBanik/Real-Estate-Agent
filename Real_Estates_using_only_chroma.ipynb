# %%
# Install pandas
pip install --quiet pandas

# %% [markdown]
# # STEP 1: SETUP OPENAI API KEY AND BASE

# %%
# All import statements used in the Step
import openai
import os

# %%
os.environ["OPENAI_API_KEY"] = "YOUR-API-KEY-HERE"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_base = os.getenv("OPENAI_API_BASE")

# %%
# GPT model used throughout the project
MODEL = "gpt-3.5-turbo"

# %% [markdown]
# # STEP 2: CREATE THE REAL ESTATE LISTINGS FOR THE CSV

# %%
# All import statements used in this Step
from pydantic import BaseModel, Field, NonNegativeInt
from typing import List
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate

# %%
# Example Instruction and Sample
INSTRUCTION = "Generate a CSV file with at least 10 real estate listing."
SAMPLE_LISTING = \
"""
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

# %%
class RealEstates(BaseModel):
    neighborhood: str = Field(description="The neighborhood in which the property is located.")
    price: NonNegativeInt = Field(description="The price of the property in USD.")
    bedrooms: NonNegativeInt = Field(description="The number of bedrooms in the property.")
    bathrooms: NonNegativeInt = Field(description="The number of bathrooms in the property.")
    house_size: NonNegativeInt = Field(description="The size of the property in sqft.")
    description: str = Field(description="A brief description of the house describing all of its pros.")
    neighborhood_description: str = Field(description="A brief description of the neighborhood describing all of its pros.")

# %%
class Listings(BaseModel):
    listings: List[RealEstates] = Field(description="A list containing Real Estate details.")

# %%
parser = PydanticOutputParser(pydantic_object=Listings)

# %%
prompt_template = PromptTemplate(
    template="{instruction}\n{sample}\n{format_instructions}",
    input_variables=["instruction", "sample"],
    partial_variables={"format_instructions": parser.get_format_instructions}
)

print(prompt_template)
# Out:
# input_variables=['instruction', 'sample'] partial_variables={'format_instructions': <bound method PydanticOutputParser.get_format_instructions of PydanticOutputParser(pydantic_object=<class '__main__.Listings'>)>} template='{instruction}\n{sample}\n{format_instructions}'

# %%
initial_query = prompt_template.format(instruction=INSTRUCTION, sample=SAMPLE_LISTING)
print(initial_query)
# Out:
# Generate a CSV file with at least 10 real estate listing.
#
# Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 2,000 sqft
#
# Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
#
# Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"listings": {"title": "Listings", "description": "A list containing Real Estate details.", "type": "array", "items": {"$ref": "#/definitions/RealEstates"}}}, "required": ["listings"], "definitions": {"RealEstates": {"title": "RealEstates", "type": "object", "properties": {"neighborhood": {"title": "Neighborhood", "description": "The neighborhood in which the property is located.", "type": "string"}, "price": {"title": "Price", "description": "The price of the property in USD.", "minimum": 0, "type": "integer"}, "bedrooms": {"title": "Bedrooms", "description": "The number of bedrooms in the property.", "minimum": 0, "type": "integer"}, "bathrooms": {"title": "Bathrooms", "description": "The number of bathrooms in the property.", "minimum": 0, "type": "integer"}, "house_size": {"title": "House Size", "description": "The size of the property in sqft.", "minimum": 0, "type": "integer"}, "description": {"title": "Description", "description": "A brief description of the house describing all of its pros.", "type": "string"}, "neighborhood_description": {"title": "Neighborhood Description", "description": "A brief description of the neighborhood describing all of its pros.", "type": "string"}}, "required": ["neighborhood", "price", "bedrooms", "bathrooms", "house_size", "description", "neighborhood_description"]}}}
# ```

# %%
llm_response = openai.ChatCompletion.create(
    model=MODEL,
    temperature=0.0,
    messages=[
        {
            "role": "user",
            "content": initial_query
        }
    ]
)

# %%
response_content = llm_response.choices[0].message.content
print(response_content)
# Out:
# {
#   "listings": [
#     {
#       "neighborhood": "Green Oaks",
#       "price": 800000,
#       "bedrooms": 3,
#       "bathrooms": 2,
#       "house_size": 2000,
#       "description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.",
#       "neighborhood_description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."
#     },
#     {
#       "neighborhood": "Sunnyvale",
#       "price": 950000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 2500,
#       "description": "Beautiful 4-bedroom, 3-bathroom home located in the desirable neighborhood of Sunnyvale. This spacious property features a modern kitchen, luxurious bathrooms, and a large backyard perfect for entertaining. Enjoy the convenience of nearby shopping centers, parks, and top-rated schools.",
#       "neighborhood_description": "Sunnyvale is known for its family-friendly atmosphere, excellent schools, and easy access to Silicon Valley tech companies. Residents can enjoy outdoor activities at the nearby parks or take a short drive to the beach for a relaxing weekend getaway."
#     },
#     {
#       "neighborhood": "Downtown Los Angeles",
#       "price": 1200000,
#       "bedrooms": 2,
#       "bathrooms": 2,
#       "house_size": 1800,
#       "description": "Luxurious 2-bedroom, 2-bathroom condo in the heart of Downtown Los Angeles. This modern unit features high-end finishes, floor-to-ceiling windows, and stunning city views. Enjoy the convenience of living in a vibrant neighborhood with easy access to restaurants, shopping, and entertainment.",
#       "neighborhood_description": "Downtown Los Angeles is a bustling urban center with a mix of historic architecture, trendy boutiques, and cultural attractions. Residents can explore the nearby museums, theaters, and art galleries, or take a short drive to the mountains for outdoor adventures."
#     },
#     {
#       "neighborhood": "Brooklyn Heights",
#       "price": 1500000,
#       "bedrooms": 5,
#       "bathrooms": 4,
#       "house_size": 3000,
#       "description": "Stunning 5-bedroom, 4-bathroom brownstone in the prestigious neighborhood of Brooklyn Heights. This historic home features original details, modern amenities, and a private garden oasis. Experience the charm of Brooklyn living with easy access to waterfront parks, trendy restaurants, and cultural attractions.",
#       "neighborhood_description": "Brooklyn Heights is a picturesque neighborhood known for its tree-lined streets, historic brownstones, and stunning views of the Manhattan skyline. Residents can enjoy a vibrant community with access to top-rated schools, boutique shops, and scenic promenades."
#     },
#     {
#       "neighborhood": "Pacific Palisades",
#       "price": 2500000,
#       "bedrooms": 6,
#       "bathrooms": 5,
#       "house_size": 4000,
#       "description": "Magnificent 6-bedroom, 5-bathroom estate in the exclusive neighborhood of Pacific Palisades. This custom-built home features high ceilings, gourmet kitchen, and a resort-style backyard with a pool and spa. Enjoy the ultimate luxury living with breathtaking ocean views and easy access to hiking trails, beaches, and upscale shopping.",
#       "neighborhood_description": "Pacific Palisades is a prestigious coastal community known for its upscale homes, celebrity residents, and scenic beauty. Residents can enjoy a relaxed lifestyle with access to world-class amenities, top-rated schools, and exclusive country clubs."
#     },
#     {
#       "neighborhood": "South Beach",
#       "price": 1800000,
#       "bedrooms": 3,
#       "bathrooms": 3,
#       "house_size": 2200,
#       "description": "Modern 3-bedroom, 3-bathroom condo in the vibrant neighborhood of South Beach. This sleek unit features an open floor plan, designer finishes, and panoramic views of the bay. Experience luxury living with access to trendy restaurants, nightlife, and cultural attractions.",
#       "neighborhood_description": "South Beach is a trendy waterfront neighborhood known for its upscale condos, art deco architecture, and lively atmosphere. Residents can enjoy a vibrant nightlife, world-class dining, and sandy beaches just steps away from their doorstep."
#     },
#     {
#       "neighborhood": "Georgetown",
#       "price": 1700000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 2800,
#       "description": "Charming 4-bedroom, 3-bathroom townhouse in the historic neighborhood of Georgetown. This elegant home features original details, modern updates, and a private courtyard perfect for outdoor entertaining. Experience the rich history and culture of Georgetown with easy access to boutique shops, cafes, and waterfront parks.",
#       "neighborhood_description": "Georgetown is a picturesque neighborhood known for its cobblestone streets, historic architecture, and vibrant community. Residents can explore the nearby museums, galleries, and theaters, or take a leisurely stroll along the scenic waterfront."
#     },
#     {
#       "neighborhood": "Nob Hill",
#       "price": 2000000,
#       "bedrooms": 3,
#       "bathrooms": 2,
#       "house_size": 2400,
#       "description": "Elegant 3-bedroom, 2-bathroom penthouse in the prestigious neighborhood of Nob Hill. This luxurious unit features high ceilings, panoramic views, and a private terrace for outdoor dining. Enjoy the ultimate urban living with access to fine dining, shopping, and cultural landmarks.",
#       "neighborhood_description": "Nob Hill is a historic neighborhood known for its grand mansions, upscale hotels, and iconic landmarks. Residents can experience the charm of old San Francisco with access to cable cars, museums, and theaters just steps away from their doorstep."
#     },
#     {
#       "neighborhood": "Coral Gables",
#       "price": 1600000,
#       "bedrooms": 5,
#       "bathrooms": 4,
#       "house_size": 3200,
#       "description": "Spacious 5-bedroom, 4-bathroom home in the prestigious neighborhood of Coral Gables. This Mediterranean-style estate features a gourmet kitchen, marble floors, and a lush tropical garden with a pool. Experience luxury living with easy access to top-rated schools, golf courses, and upscale shopping.",
#       "neighborhood_description": "Coral Gables is a picturesque neighborhood known for its tree-lined streets, historic architecture, and vibrant community. Residents can enjoy a relaxed lifestyle with access to parks, art galleries, and cultural events throughout the year."
#     },
#     {
#       "neighborhood": "Beverly Hills",
#       "price": 3000000,
#       "bedrooms": 6,
#       "bathrooms": 6,
#       "house_size": 5000,
#       "description": "Exquisite 6-bedroom, 6-bathroom mansion in the prestigious neighborhood of Beverly Hills. This luxurious estate features a grand foyer, formal living and dining rooms, and a private backyard with a pool and spa. Enjoy the ultimate in luxury living with easy access to world-class shopping, dining, and entertainment.",
#       "neighborhood_description": "Beverly Hills is an exclusive neighborhood known for its celebrity residents, upscale homes, and luxury boutiques. Residents can experience the glamour of Hollywood with access to top-rated schools, fine dining, and cultural attractions just minutes away."
#     }
#   ]
# }

# %% [markdown]
# # STEP 3: CREATE THE CSV FROM THE LISTINGS

# %%
# All import statements used in this step
import pandas as pd

# %%
parsed_content = parser.parse(response_content)

# %%
listings = parsed_content.listings

# %%
df = pd.DataFrame([listing.dict() for listing in listings])
df.head()
# Out:
#            neighborhood    price  bedrooms  bathrooms  house_size  \
# 0            Green Oaks   800000         3          2        2000
# 1             Sunnyvale   950000         4          3        2500
# 2  Downtown Los Angeles  1200000         2          2        1800
# 3      Brooklyn Heights  1500000         5          4        3000
# 4     Pacific Palisades  2500000         6          5        4000
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Beautiful 4-bedroom, 3-bathroom home located i...
# 2  Luxurious 2-bedroom, 2-bathroom condo in the h...
# 3  Stunning 5-bedroom, 4-bathroom brownstone in t...
# 4  Magnificent 6-bedroom, 5-bathroom estate in th...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Sunnyvale is known for its family-friendly atm...
# 2  Downtown Los Angeles is a bustling urban cente...
# 3  Brooklyn Heights is a picturesque neighborhood...
# 4  Pacific Palisades is a prestigious coastal com...

# %%
df.to_csv("Real_Estates.csv")

# %% [markdown]
# # STEP 4: CREATE THE CHROMA DB VECTOR DATABASE

# %%
# All import statements used in this step
import pandas as pd
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
df = pd.read_csv("Real_Estates.csv")

# %%
CHROMA_PATH = "content/chroma"

# %%
embedding_function = OpenAIEmbeddings()

# %%
documents = []
for index, row in df.iterrows():
    documents.append(Document(page_content=row["description"], metadata={"id": str(index)}))
print(f"Successfully created {len(documents)} documents from CSV.")
# Out:
# Successfully created 10 documents from CSV.

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=100,
    length_function=len,
    add_start_index=True
)

# %%
chunks = text_splitter.split_documents(documents)
print(f"Successfully created {len(chunks)} chunks from {len(documents)} documents.")
# Out:
# Successfully created 16 chunks from 10 documents.

# %%
if os.path.exists(CHROMA_PATH):
    shutil.rmtree(CHROMA_PATH)

# %%
db = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_function,
    persist_directory=CHROMA_PATH
)

# %%
db.persist()
print(f"Successfully created ChromaDB Vector Database at {CHROMA_PATH}")
# Out:
# Successfully created ChromaDB Vector Database at content/chroma

# %% [markdown]
# # STEP 5: SEMANTIC SEARCH USING USER INPUT

# %%
# All Import statements used in this step
from langchain.prompts import ChatPromptTemplate

# %%
user_query = input("Describe your dream house: ")
# Out:
# Describe your dream house: A comfortable three-bedroom house with a spacious kitchen and a cozy living room.

# %%
BASIC_PROMPT_TEMPLATE = """
Based on the following context:

{context}

---

Answer the following question: {question}
"""

# %%
def semantic_search(question, template):
    db = Chroma(
        persist_directory=CHROMA_PATH,
        embedding_function=embedding_function
    )
    
    top_3 = db.similarity_search_with_relevance_scores(query=question, k=3)
    if len(top_3) == 0 or top_3[0][1] < 0.7:
        print("Unable to find relevant matches!")
        return
    else:
        context_text = "\n----\n".join([doc.page_content for doc, _score in top_3])
        prompt_template = PromptTemplate(
            template=template,
            input_variables=["context", "question"]
        )
        prompt = prompt_template.format(context=context_text, question=question)
        print(f"Generated Prompt:\n{prompt}")
        return prompt

# %%
result = semantic_search(question=user_query, template=BASIC_PROMPT_TEMPLATE)
# Out:
# Generated Prompt:
#
# Based on the following context:
#
# Beautiful 4-bedroom, 3-bathroom home located in the desirable neighborhood of Sunnyvale. This spacious property features a modern kitchen, luxurious bathrooms, and a large backyard perfect for entertaining. Enjoy the convenience of nearby shopping centers, parks, and top-rated schools.
# ----
# Charming 4-bedroom, 3-bathroom townhouse in the historic neighborhood of Georgetown. This elegant home features original details, modern updates, and a private courtyard perfect for outdoor entertaining. Experience the rich history and culture of Georgetown with easy access to boutique shops, cafes,
# ----
# Modern 3-bedroom, 3-bathroom condo in the vibrant neighborhood of South Beach. This sleek unit features an open floor plan, designer finishes, and panoramic views of the bay. Experience luxury living with access to trendy restaurants, nightlife, and cultural attractions.
#
# ---
#
# Answer the following question: A comfortable three-bedroom house with a spacious kitchen and a cozy living room.

# %%
llm_response = openai.ChatCompletion.create(
    model=MODEL,
    temperature=0.0,
    messages=[
        {
            "role": "user",
            "content": result
        }
    ]
)

# %%
print(llm_response.choices[0].message.content)
# Out:
# The third option, a modern 3-bedroom, 3-bathroom condo in the vibrant neighborhood of South Beach, may not be the best fit for someone looking for a comfortable three-bedroom house with a spacious kitchen and a cozy living room. The first option, a beautiful 4-bedroom, 3-bathroom home located in the desirable neighborhood of Sunnyvale, would likely be a better match for those specific criteria.

# %% [markdown]
# ### AUGMENTING SEARCH USING SYSTEM PROMPT

# %%
system_prompt = """
You are LLMRealtor, a highly experienced Real Estate Agent who has sold hundreds of properties.
You are polite, warm and friendly.
You will be given a three Real Estates that are the closest to a buyer's preferences.
Your task is to positively convince them that these three properties are the best for them and give them proper reasons to buy one of these properties. 
**Ultimately, suggest the best property according to the *buyer's preferences* provided.**
"""

# %%
AUGMENTED_PROMPT = """
REAL ESTATES CLOSEST TO THE BUYER'S PREFERENCES:

{context}

---

BUYER'S ORIGINAL PREFERENCE: {question}
"""

# %%
result = semantic_search(question=user_query, template=AUGMENTED_PROMPT)
# Out:
# Generated Prompt:
#
# REAL ESTATES CLOSEST TO THE BUYER'S PREFERENCES:
#
# Beautiful 4-bedroom, 3-bathroom home located in the desirable neighborhood of Sunnyvale. This spacious property features a modern kitchen, luxurious bathrooms, and a large backyard perfect for entertaining. Enjoy the convenience of nearby shopping centers, parks, and top-rated schools.
# ----
# Charming 4-bedroom, 3-bathroom townhouse in the historic neighborhood of Georgetown. This elegant home features original details, modern updates, and a private courtyard perfect for outdoor entertaining. Experience the rich history and culture of Georgetown with easy access to boutique shops, cafes,
# ----
# Modern 3-bedroom, 3-bathroom condo in the vibrant neighborhood of South Beach. This sleek unit features an open floor plan, designer finishes, and panoramic views of the bay. Experience luxury living with access to trendy restaurants, nightlife, and cultural attractions.
#
# ---
#
# BUYER'S ORIGINAL PREFERENCE: A comfortable three-bedroom house with a spacious kitchen and a cozy living room.

# %%
llm_response = openai.ChatCompletion.create(
    model=MODEL,
    temperature=0.7,
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": result
        }
    ]
)

# %%
print(llm_response.choices[0].message.content)
# Out:
# Hello! It's a pleasure to assist you in finding your perfect home. Based on your preferences for a comfortable three-bedroom house with a spacious kitchen and a cozy living room, I have selected three properties that closely match what you are looking for.
#
# 1. The beautiful 4-bedroom, 3-bathroom home in Sunnyvale offers a spacious kitchen and a cozy living room, perfect for relaxing with your loved ones. The large backyard provides a great space for entertaining and enjoying the outdoors.
#
# 2. The charming 4-bedroom, 3-bathroom townhouse in Georgetown also features a spacious kitchen and a cozy living room. The private courtyard adds a touch of outdoor charm, ideal for intimate gatherings and relaxation.
#
# 3. The modern 3-bedroom, 3-bathroom condo in South Beach may have one less bedroom, but it boasts a spacious open floor plan with a designer kitchen and a comfortable living area. The panoramic views of the bay add a unique touch to the property.
#
# Considering your preference for a comfortable three-bedroom house with a spacious kitchen and a cozy living room, I would recommend the beautiful 4-bedroom, 3-bathroom home in Sunnyvale. It not only meets your desired criteria but also offers the added benefit of a large backyard for entertainment. The proximity to shopping centers, parks, and schools makes it an ideal choice for both comfort and convenience. This property combines all the features you are looking for in a home and more.
